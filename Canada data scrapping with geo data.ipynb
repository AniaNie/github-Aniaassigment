# %% [markdown]
# # This notebook will be used for the capstone project

# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # Scrape data from wiki page and write it to text file

# %%
source = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text

soup = BeautifulSoup(source, 'lxml')
with open('Canada_codes.txt', 'w') as fo:
    for tr in soup.find_all('tr'):
            tds = tr.find_all('td')
            if not tds:
                continue
            Postalcode, Borough, Neighbourhood = [td.text.strip() for td in tds[:4]]
            print('; '.join([Postalcode, Borough, Neighbourhood]), file=fo)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-128-3da2f64771c7> in <module>
#       7             if not tds:
#       8                 continue
# ----> 9             Postalcode, Borough, Neighbourhood = [td.text.strip() for td in tds[:4]]
#      10             print('; '.join([Postalcode, Borough, Neighbourhood]), file=fo)
#
# ValueError: not enough values to unpack (expected 3, got 1)

# %% [markdown]
# # Import text file created from scraping

# %%
data = pd.read_csv('Canada_codes.txt', sep=";", header=None)
data.columns = ["Postalcode", "Borough", "Neighbourhood"]

# %% [markdown]
# # Filter out 'not assigned'

# %%
Canada_data = data[(data['Borough'].astype(str)).str.contains(r'^(?:(?!Not assigned).)*$')]

# %%
Canada_data
# Out:
#     Postalcode            Borough  \
# 2          M3A         North York
# 3          M4A         North York
# 4          M5A   Downtown Toronto
# 5          M5A   Downtown Toronto
# 6          M6A         North York
# 7          M6A         North York
# 8          M7A       Queen's Park
# 10         M9A          Etobicoke
# 11         M1B        Scarborough
# 12         M1B        Scarborough
# 14         M3B         North York
# 15         M4B          East York
# 16         M4B          East York
# 17         M5B   Downtown Toronto
# 18         M5B   Downtown Toronto
# 19         M6B         North York
# 22         M9B          Etobicoke
# 23         M9B          Etobicoke
# 24         M9B          Etobicoke
# 25         M9B          Etobicoke
# 26         M9B          Etobicoke
# 27         M1C        Scarborough
# 28         M1C        Scarborough
# 29         M1C        Scarborough
# 31         M3C         North York
# 32         M3C         North York
# 33         M4C          East York
# 34         M5C   Downtown Toronto
# 35         M6C               York
# 38         M9C          Etobicoke
# ..         ...                ...
# 235        M9V          Etobicoke
# 236        M1W        Scarborough
# 239        M4W   Downtown Toronto
# 240        M5W   Downtown Toronto
# 243        M8W          Etobicoke
# 244        M8W          Etobicoke
# 245        M9W          Etobicoke
# 246        M1X        Scarborough
# 249        M4X   Downtown Toronto
# 250        M4X   Downtown Toronto
# 251        M5X   Downtown Toronto
# 252        M5X   Downtown Toronto
# 255        M8X          Etobicoke
# 256        M8X          Etobicoke
# 257        M8X          Etobicoke
# 262        M4Y   Downtown Toronto
# 265        M7Y       East Toronto
# 266        M8Y          Etobicoke
# 267        M8Y          Etobicoke
# 268        M8Y          Etobicoke
# 269        M8Y          Etobicoke
# 270        M8Y          Etobicoke
# 271        M8Y          Etobicoke
# 272        M8Y          Etobicoke
# 273        M8Y          Etobicoke
# 282        M8Z          Etobicoke
# 283        M8Z          Etobicoke
# 284        M8Z          Etobicoke
# 285        M8Z          Etobicoke
# 286        M8Z          Etobicoke
#
#                                          Neighbourhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                                         Harbourfront
# 5                                          Regent Park
# 6                                     Lawrence Heights
# 7                                       Lawrence Manor
# 8                                         Not assigned
# 10                                    Islington Avenue
# 11                                               Rouge
# 12                                             Malvern
# 14                                     Don Mills North
# 15                                    Woodbine Gardens
# 16                                       Parkview Hill
# 17                                             Ryerson
# 18                                     Garden District
# 19                                           Glencairn
# 22                                          Cloverdale
# 23                                           Islington
# 24                                        Martin Grove
# 25                                    Princess Gardens
# 26                                     West Deane Park
# 27                                      Highland Creek
# 28                                          Rouge Hill
# 29                                          Port Union
# 31                                     Flemingdon Park
# 32                                     Don Mills South
# 33                                    Woodbine Heights
# 34                                      St. James Town
# 35                                  Humewood-Cedarvale
# 38                                   Bloordale Gardens
# ..                                                 ...
# 235                                        Thistletown
# 236                                    L'Amoreaux West
# 239                                           Rosedale
# 240                    Stn A PO Boxes 25 The Esplanade
# 243                                          Alderwood
# 244                                        Long Branch
# 245                                          Northwest
# 246                                        Upper Rouge
# 249                                        Cabbagetown
# 250                                     St. James Town
# 251                               First Canadian Place
# 252                                   Underground city
# 255                                       The Kingsway
# 256                                    Montgomery Road
# 257                                     Old Mill North
# 262                               Church and Wellesley
# 265   Business Reply Mail Processing Centre 969 Eas...
# 266                                         Humber Bay
# 267                                   King's Mill Park
# 268                           Kingsway Park South East
# 269                                          Mimico NE
# 270                                     Old Mill South
# 271                                 The Queensway East
# 272                              Royal York South East
# 273                                           Sunnylea
# 282                           Kingsway Park South West
# 283                                          Mimico NW
# 284                                 The Queensway West
# 285                              Royal York South West
# 286                                     South of Bloor
#
# [211 rows x 3 columns]

# %% [markdown]
# # Join neighbourhoods

# %%
Canada_data.Neighbourhood = Canada_data.Neighbourhood.astype(str)
df1 = pd.DataFrame(Canada_data.groupby(['Postalcode', 'Borough'])['Neighbourhood'].apply(', '.join).reset_index())
df1
# Out:
#     Postalcode            Borough  \
# 0          M1B        Scarborough
# 1          M1C        Scarborough
# 2          M1E        Scarborough
# 3          M1G        Scarborough
# 4          M1H        Scarborough
# 5          M1J        Scarborough
# 6          M1K        Scarborough
# 7          M1L        Scarborough
# 8          M1M        Scarborough
# 9          M1N        Scarborough
# 10         M1P        Scarborough
# 11         M1R        Scarborough
# 12         M1S        Scarborough
# 13         M1T        Scarborough
# 14         M1V        Scarborough
# 15         M1W        Scarborough
# 16         M1X        Scarborough
# 17         M2H         North York
# 18         M2J         North York
# 19         M2K         North York
# 20         M2L         North York
# 21         M2M         North York
# 22         M2N         North York
# 23         M2P         North York
# 24         M2R         North York
# 25         M3A         North York
# 26         M3B         North York
# 27         M3C         North York
# 28         M3H         North York
# 29         M3J         North York
# ..         ...                ...
# 73         M6C               York
# 74         M6E               York
# 75         M6G   Downtown Toronto
# 76         M6H       West Toronto
# 77         M6J       West Toronto
# 78         M6K       West Toronto
# 79         M6L         North York
# 80         M6M               York
# 81         M6N               York
# 82         M6P       West Toronto
# 83         M6R       West Toronto
# 84         M6S       West Toronto
# 85         M7A       Queen's Park
# 86         M7R        Mississauga
# 87         M7Y       East Toronto
# 88         M8V          Etobicoke
# 89         M8W          Etobicoke
# 90         M8X          Etobicoke
# 91         M8Y          Etobicoke
# 92         M8Z          Etobicoke
# 93         M9A          Etobicoke
# 94         M9B          Etobicoke
# 95         M9C          Etobicoke
# 96         M9L         North York
# 97         M9M         North York
# 98         M9N               York
# 99         M9P          Etobicoke
# 100        M9R          Etobicoke
# 101        M9V          Etobicoke
# 102        M9W          Etobicoke
#
#                                          Neighbourhood
# 0                                      Rouge,  Malvern
# 1             Highland Creek,  Rouge Hill,  Port Union
# 2                  Guildwood,  Morningside,  West Hill
# 3                                               Woburn
# 4                                            Cedarbrae
# 5                                  Scarborough Village
# 6        East Birchmount Park,  Ionview,  Kennedy Park
# 7                    Clairlea,  Golden Mile,  Oakridge
# 8     Cliffcrest,  Cliffside,  Scarborough Village ...
# 9                         Birch Cliff,  Cliffside West
# 10    Dorset Park,  Scarborough Town Centre,  Wexfo...
# 11                                  Maryvale,  Wexford
# 12                                           Agincourt
# 13           Clarks Corners,  Sullivan,  Tam O'Shanter
# 14    Agincourt North,  L'Amoreaux East,  Milliken,...
# 15                                     L'Amoreaux West
# 16                                         Upper Rouge
# 17                                   Hillcrest Village
# 18                      Fairview,  Henry Farm,  Oriole
# 19                                     Bayview Village
# 20                           Silver Hills,  York Mills
# 21                            Newtonbrook,  Willowdale
# 22                                    Willowdale South
# 23                                     York Mills West
# 24                                     Willowdale West
# 25                                           Parkwoods
# 26                                     Don Mills North
# 27                   Flemingdon Park,  Don Mills South
# 28    Bathurst Manor,  Downsview North,  Wilson Hei...
# 29                    Northwood Park,  York University
# ..                                                 ...
# 73                                  Humewood-Cedarvale
# 74                                 Caledonia-Fairbanks
# 75                                            Christie
# 76                       Dovercourt Village,  Dufferin
# 77                           Little Portugal,  Trinity
# 78      Brockton,  Exhibition Place,  Parkdale Village
# 79                Downsview,  North Park,  Upwood Park
# 80    Del Ray,  Keelesdale,  Mount Dennis,  Silvert...
# 81                      The Junction North,  Runnymede
# 82                      High Park,  The Junction South
# 83                             Parkdale,  Roncesvalles
# 84                                 Runnymede,  Swansea
# 85                                        Not assigned
# 86               Canada Post Gateway Processing Centre
# 87    Business Reply Mail Processing Centre 969 Eas...
# 88      Humber Bay Shores,  Mimico South,  New Toronto
# 89                             Alderwood,  Long Branch
# 90     The Kingsway,  Montgomery Road,  Old Mill North
# 91    Humber Bay,  King's Mill Park,  Kingsway Park...
# 92    Kingsway Park South West,  Mimico NW,  The Qu...
# 93                                    Islington Avenue
# 94    Cloverdale,  Islington,  Martin Grove,  Princ...
# 95    Bloordale Gardens,  Eringate,  Markland Wood,...
# 96                                       Humber Summit
# 97                                   Emery,  Humberlea
# 98                                              Weston
# 99                                           Westmount
# 100   Kingsview Village,  Martin Grove Gardens,  Ri...
# 101   Albion Gardens,  Beaumond Heights,  Humbergat...
# 102                                          Northwest
#
# [103 rows x 3 columns]

# %%
Canada_geo = pd.read_csv('Geospatial_Coordinates.csv')

# %%
Canada_geo
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# 5           M1J  43.744734 -79.239476
# 6           M1K  43.727929 -79.262029
# 7           M1L  43.711112 -79.284577
# 8           M1M  43.716316 -79.239476
# 9           M1N  43.692657 -79.264848
# 10          M1P  43.757410 -79.273304
# 11          M1R  43.750072 -79.295849
# 12          M1S  43.794200 -79.262029
# 13          M1T  43.781638 -79.304302
# 14          M1V  43.815252 -79.284577
# 15          M1W  43.799525 -79.318389
# 16          M1X  43.836125 -79.205636
# 17          M2H  43.803762 -79.363452
# 18          M2J  43.778517 -79.346556
# 19          M2K  43.786947 -79.385975
# 20          M2L  43.757490 -79.374714
# 21          M2M  43.789053 -79.408493
# 22          M2N  43.770120 -79.408493
# 23          M2P  43.752758 -79.400049
# 24          M2R  43.782736 -79.442259
# 25          M3A  43.753259 -79.329656
# 26          M3B  43.745906 -79.352188
# 27          M3C  43.725900 -79.340923
# 28          M3H  43.754328 -79.442259
# 29          M3J  43.767980 -79.487262
# ..          ...        ...        ...
# 73          M6C  43.693781 -79.428191
# 74          M6E  43.689026 -79.453512
# 75          M6G  43.669542 -79.422564
# 76          M6H  43.669005 -79.442259
# 77          M6J  43.647927 -79.419750
# 78          M6K  43.636847 -79.428191
# 79          M6L  43.713756 -79.490074
# 80          M6M  43.691116 -79.476013
# 81          M6N  43.673185 -79.487262
# 82          M6P  43.661608 -79.464763
# 83          M6R  43.648960 -79.456325
# 84          M6S  43.651571 -79.484450
# 85          M7A  43.662301 -79.389494
# 86          M7R  43.636966 -79.615819
# 87          M7Y  43.662744 -79.321558
# 88          M8V  43.605647 -79.501321
# 89          M8W  43.602414 -79.543484
# 90          M8X  43.653654 -79.506944
# 91          M8Y  43.636258 -79.498509
# 92          M8Z  43.628841 -79.520999
# 93          M9A  43.667856 -79.532242
# 94          M9B  43.650943 -79.554724
# 95          M9C  43.643515 -79.577201
# 96          M9L  43.756303 -79.565963
# 97          M9M  43.724766 -79.532242
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %% [markdown]
# # Join geo data

# %%
Canada_data_geo = Canada_data.join(Canada_geo.set_index('Postal Code'), on='Postalcode')

# %%
Canada_anlysis
# Out:
#     Postalcode      Borough         Neighbourhood   Latitude  Longitude
# 2          M3A   North York             Parkwoods  43.753259 -79.329656
# 3          M4A   North York      Victoria Village  43.725882 -79.315572
# 6          M6A   North York      Lawrence Heights  43.718518 -79.464763
# 7          M6A   North York        Lawrence Manor  43.718518 -79.464763
# 14         M3B   North York       Don Mills North  43.745906 -79.352188
# 19         M6B   North York             Glencairn  43.709577 -79.445073
# 31         M3C   North York       Flemingdon Park  43.725900 -79.340923
# 32         M3C   North York       Don Mills South  43.725900 -79.340923
# 63         M2H   North York     Hillcrest Village  43.803762 -79.363452
# 64         M3H   North York        Bathurst Manor  43.754328 -79.442259
# 65         M3H   North York       Downsview North  43.754328 -79.442259
# 66         M3H   North York        Wilson Heights  43.754328 -79.442259
# 77         M2J   North York              Fairview  43.778517 -79.346556
# 78         M2J   North York            Henry Farm  43.778517 -79.346556
# 79         M2J   North York                Oriole  43.778517 -79.346556
# 80         M3J   North York        Northwood Park  43.767980 -79.487262
# 81         M3J   North York       York University  43.767980 -79.487262
# 94         M2K   North York       Bayview Village  43.786947 -79.385975
# 95         M3K   North York           CFB Toronto  43.737473 -79.464763
# 96         M3K   North York        Downsview East  43.737473 -79.464763
# 110        M2L   North York          Silver Hills  43.757490 -79.374714
# 111        M2L   North York            York Mills  43.757490 -79.374714
# 112        M3L   North York        Downsview West  43.739015 -79.506944
# 117        M6L   North York             Downsview  43.713756 -79.490074
# 118        M6L   North York            North Park  43.713756 -79.490074
# 119        M6L   North York           Upwood Park  43.713756 -79.490074
# 122        M9L   North York         Humber Summit  43.756303 -79.565963
# 126        M2M   North York           Newtonbrook  43.789053 -79.408493
# 127        M2M   North York            Willowdale  43.789053 -79.408493
# 128        M3M   North York     Downsview Central  43.728496 -79.495697
# 130        M5M   North York          Bedford Park  43.733283 -79.419750
# 131        M5M   North York   Lawrence Manor East  43.733283 -79.419750
# 138        M9M   North York                 Emery  43.724766 -79.532242
# 139        M9M   North York             Humberlea  43.724766 -79.532242
# 142        M2N   North York      Willowdale South  43.770120 -79.408493
# 143        M3N   North York   Downsview Northwest  43.761631 -79.520999
# 154        M2P   North York       York Mills West  43.752758 -79.400049
# 166        M2R   North York       Willowdale West  43.782736 -79.442259

# %% [markdown]
# # Analysis

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Collecting package metadata: ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\AniaIgor\Anaconda3
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.7.5                |           py37_0         3.0 MB  conda-forge
#     conda-package-handling-1.3.10|           py37_0         277 KB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   conda-package-han~ conda-forge/win-64::conda-package-handling-1.3.10-py37_0
#   geographiclib      conda-forge/noarch::geographiclib-1.49-py_0
#   geopy              conda-forge/noarch::geopy-1.20.0-py_0
#
# The following packages will be UPDATED:
#
#   conda                                       4.6.14-py37_0 --> 4.7.5-py37_0
#
#
#
# Downloading and Extracting Packages
#
# conda-4.7.5          | 3.0 MB    |            |   0%
# conda-4.7.5          | 3.0 MB    |            |   0%
# conda-4.7.5          | 3.0 MB    | #2         |  12%
# conda-4.7.5          | 3.0 MB    | #8         |  19%
# conda-4.7.5          | 3.0 MB    | ##4        |  25%
# conda-4.7.5          | 3.0 MB    | ###5       |  36%
# conda-4.7.5          | 3.0 MB    | ####1      |  42%
# conda-4.7.5          | 3.0 MB    | ####8      |  48%
# conda-4.7.5          | 3.0 MB    | #####3     |  53%
# conda-4.7.5          | 3.0 MB    | #####8     |  58%
# conda-4.7.5          | 3.0 MB    | ######6    |  66%
# conda-4.7.5          | 3.0 MB    | #######1   |  71%
# conda-4.7.5          | 3.0 MB    | #######9   |  79%
# conda-4.7.5          | 3.0 MB    | ########4  |  84%
# conda-4.7.5          | 3.0 MB    | ########8  |  89%
# conda-4.7.5          | 3.0 MB    | #########6 |  96%
# conda-4.7.5          | 3.0 MB    | ########## | 100%
#
# conda-package-handli | 277 KB    |            |   0%
# conda-package-handli | 277 KB    | ######     |  61%
# conda-package-handli | 277 KB    | ########## | 100%
#
# geopy-1.20.0         | 57 KB     |            |   0%
# geopy-1.20.0         | 57 KB     | ##         |  21%
# geopy-1.20.0         | 57 KB     | #########2 |  92%
# geopy-1.20.0         | 57 KB     | ########## | 100%
#
# geographiclib-1.49   | 32 KB     |            |   0%
# geographiclib-1.49   | 32 KB     | ###7       |  37%
# geographiclib-1.49   | 32 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
# WARNING conda.base.context:use_only_tar_bz2(632): Conda is constrained to only using the old .tar.bz2 file format because you have conda-build installed, and it is <3.18.3.  Update or remove conda-build to get smaller downloads and faster extractions.
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = '5SYIVSRH0SZI5JPHH253VQLHTYNPZR1W3Z0TI5LLB0B1XSGR' # your Foursquare ID
CLIENT_SECRET = 'V0AARCEJJQSIYRSCMHTU4RWCALUYC1Q4KZWBIQWNFDKHQ3PO' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 5SYIVSRH0SZI5JPHH253VQLHTYNPZR1W3Z0TI5LLB0B1XSGR
# CLIENT_SECRET:V0AARCEJJQSIYRSCMHTU4RWCALUYC1Q4KZWBIQWNFDKHQ3PO

# %% [markdown]
# # Select subset of data to anlyse one area

# %%
Canada_anlysis = Canada_data_geo[(Canada_data_geo['Borough'].astype(str)).str.contains('North York')]

# %%
# Select one neighbourhood's coordinates to analyse: Lawrence Heights
Canada_anlysis
# Out:
#     Postalcode      Borough         Neighbourhood   Latitude  Longitude
# 2          M3A   North York             Parkwoods  43.753259 -79.329656
# 3          M4A   North York      Victoria Village  43.725882 -79.315572
# 6          M6A   North York      Lawrence Heights  43.718518 -79.464763
# 7          M6A   North York        Lawrence Manor  43.718518 -79.464763
# 14         M3B   North York       Don Mills North  43.745906 -79.352188
# 19         M6B   North York             Glencairn  43.709577 -79.445073
# 31         M3C   North York       Flemingdon Park  43.725900 -79.340923
# 32         M3C   North York       Don Mills South  43.725900 -79.340923
# 63         M2H   North York     Hillcrest Village  43.803762 -79.363452
# 64         M3H   North York        Bathurst Manor  43.754328 -79.442259
# 65         M3H   North York       Downsview North  43.754328 -79.442259
# 66         M3H   North York        Wilson Heights  43.754328 -79.442259
# 77         M2J   North York              Fairview  43.778517 -79.346556
# 78         M2J   North York            Henry Farm  43.778517 -79.346556
# 79         M2J   North York                Oriole  43.778517 -79.346556
# 80         M3J   North York        Northwood Park  43.767980 -79.487262
# 81         M3J   North York       York University  43.767980 -79.487262
# 94         M2K   North York       Bayview Village  43.786947 -79.385975
# 95         M3K   North York           CFB Toronto  43.737473 -79.464763
# 96         M3K   North York        Downsview East  43.737473 -79.464763
# 110        M2L   North York          Silver Hills  43.757490 -79.374714
# 111        M2L   North York            York Mills  43.757490 -79.374714
# 112        M3L   North York        Downsview West  43.739015 -79.506944
# 117        M6L   North York             Downsview  43.713756 -79.490074
# 118        M6L   North York            North Park  43.713756 -79.490074
# 119        M6L   North York           Upwood Park  43.713756 -79.490074
# 122        M9L   North York         Humber Summit  43.756303 -79.565963
# 126        M2M   North York           Newtonbrook  43.789053 -79.408493
# 127        M2M   North York            Willowdale  43.789053 -79.408493
# 128        M3M   North York     Downsview Central  43.728496 -79.495697
# 130        M5M   North York          Bedford Park  43.733283 -79.419750
# 131        M5M   North York   Lawrence Manor East  43.733283 -79.419750
# 138        M9M   North York                 Emery  43.724766 -79.532242
# 139        M9M   North York             Humberlea  43.724766 -79.532242
# 142        M2N   North York      Willowdale South  43.770120 -79.408493
# 143        M3N   North York   Downsview Northwest  43.761631 -79.520999
# 154        M2P   North York       York Mills West  43.752758 -79.400049
# 166        M2R   North York       Willowdale West  43.782736 -79.442259

# %%
# set parameters to use to get the data from foursquere
geolocator = Nominatim(user_agent="foursquare_agent")
latitude = 43.718518
longitude = -79.464763
search_query = 'Italian'
radius = 5000

# %%
# quesry the data from foursquere
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=5SYIVSRH0SZI5JPHH253VQLHTYNPZR1W3Z0TI5LLB0B1XSGR&client_secret=V0AARCEJJQSIYRSCMHTU4RWCALUYC1Q4KZWBIQWNFDKHQ3PO&ll=43.718518,-79.464763&v=20180604&query=Italian&radius=5000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d1283ece0c0c9002cc2c5a1'},
#  'response': {'venues': [{'id': '566344c9498eedf4e11af0fa',
#     'name': "Jamie's Italian",
#     'location': {'address': '3401 Dufferin St',
#      'crossStreet': 'Allen Road and 401',
#      'lat': 43.72668644119483,
#      'lng': -79.45313253527624,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.72668644119483,
#        'lng': -79.45313253527624}],
#      'distance': 1304,
#      'postalCode': 'M6A 2T9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['3401 Dufferin St (Allen Road and 401)',
#       'Toronto ON M6A 2T9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1561494509',
#     'hasPerk': False},
#    {'id': '4aedafd1f964a52025ce21e3',
#     'name': 'Commisso Bros. & Racco Italian Bakery',
#     'location': {'address': '8 Kincort Street',
#      'crossStreet': 'Castlefield and Kincort',
#      'lat': 43.69762110821487,
#      'lng': -79.46854960738862,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.69762110821487,
#        'lng': -79.46854960738862}],
#      'distance': 2346,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['8 Kincort Street (Castlefield and Kincort)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1561494509',
#     'hasPerk': False},
#    {'id': '51830da6498eafb14b40f22c',
#     'name': 'San Genaro Italian Eatery',
#     'location': {'address': '3500 Dufferin St',
#      'lat': 43.720341992045576,
#      'lng': -79.45582775403308,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.720341992045576,
#        'lng': -79.45582775403308}],
#      'distance': 746,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['3500 Dufferin St', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1561494509',
#     'hasPerk': False},
#    {'id': '52430d7611d2b3a076a88132',
#     'name': 'Italian canadian savings and credit union',
#     'location': {'address': 'Dufferin',
#      'lat': 43.708356831594756,
#      'lng': -79.45387735651484,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.708356831594756,
#        'lng': -79.45387735651484}],
#      'distance': 1430,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Dufferin', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1561494509',
#     'hasPerk': False},
#    {'id': '4fca400ae4b0ba2d58c1a97f',
#     'name': 'La Paloma Italian Gelateria & Cafe',
#     'location': {'lat': 43.726174099609494,
#      'lng': -79.45231700869552,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.726174099609494,
#        'lng': -79.45231700869552}],
#      'distance': 1314,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c9941735',
#       'name': 'Ice Cream Shop',
#       'pluralName': 'Ice Cream Shops',
#       'shortName': 'Ice Cream',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1561494509',
#     'hasPerk': False},
#    {'id': '52b5da0e498e96708cf1c974',
#     'name': "Cumpari's Italian Eatery",
#     'location': {'address': '3610 dufferin street',
#      'crossStreet': 'Dufferin/Wilson',
#      'lat': 43.732118278214536,
#      'lng': -79.45992070716429,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.732118278214536,
#        'lng': -79.45992070716429}],
#      'distance': 1563,
#      'postalCode': 'M3K 1N7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['3610 dufferin street (Dufferin/Wilson)',
#       'Toronto ON M3K 1N7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1561494509',
#     'hasPerk': False},
#    {'id': '546e313c498ea838219b4ce7',
#     'name': 'The Italian Sandwich',
#     'location': {'address': '242 Rushton Road',
#      'lat': 43.680377,
#      'lng': -79.427523,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.680377,
#        'lng': -79.427523}],
#      'distance': 5197,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['242 Rushton Road', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b55',
#       'name': 'Trailer Park',
#       'pluralName': 'Trailer Parks',
#       'shortName': 'Trailer Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/home_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1561494509',
#     'hasPerk': False},
#    {'id': '4b9fbb53f964a5206a3937e3',
#     'name': 'Italian Cafe',
#     'location': {'address': '2200 Yonge St',
#      'lat': 43.723770149039666,
#      'lng': -79.39757272339696,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.723770149039666,
#        'lng': -79.39757272339696}],
#      'distance': 5437,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['2200 Yonge St', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1561494509',
#     'hasPerk': False},
#    {'id': '4de3e16efa7651589f21395e',
#     'name': 'Saggio Italian Eatery & Espresdo Bar',
#     'location': {'lat': 43.758340332929556,
#      'lng': -79.4767411031542,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.758340332929556,
#        'lng': -79.4767411031542}],
#      'distance': 4536,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1561494509',
#     'hasPerk': False},
#    {'id': '4cfc22012d80a14304854fd8',
#     'name': 'Catania Italian Cuisine',
#     'location': {'lat': 43.680797,
#      'lng': -79.43057,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.680797,
#        'lng': -79.43057}],
#      'distance': 5020,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1561494509',
#     'hasPerk': False},
#    {'id': '4e8218e1775b313c2afa5d8d',
#     'name': 'Agio Italian Ristorante',
#     'location': {'address': '1351 St Clair West',
#      'crossStreet': 'Lansdowne',
#      'lat': 43.67615560949629,
#      'lng': -79.45057434036129,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.67615560949629,
#        'lng': -79.45057434036129}],
#      'distance': 4852,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1351 St Clair West (Lansdowne)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1561494509',
#     'hasPerk': False},
#    {'id': '4c4f0fa6fb742d7fda08542f',
#     'name': 'Il vagabondo',
#     'location': {'address': '2700 Dufferin Street',
#      'lat': 43.70147993924583,
#      'lng': -79.45244337587796,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.70147993924583,
#        'lng': -79.45244337587796}],
#      'distance': 2140,
#      'postalCode': 'm6b 4j3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['2700 Dufferin Street',
#       'Toronto ON m6b 4j3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1561494509',
#     'hasPerk': False},
#    {'id': '4cfe726a084f54811f969009',
#     'name': "Dora's Italian",
#     'location': {'lat': 43.76812,
#      'lng': -79.475147,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.76812,
#        'lng': -79.475147}],
#      'distance': 5584,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1561494509',
#     'hasPerk': False},
#    {'id': '4b199b46f964a5205be023e3',
#     'name': 'Jolly II Italian Restaurant',
#     'location': {'address': '2625 Weston',
#      'crossStreet': '401',
#      'lat': 43.711946052767104,
#      'lng': -79.53150957322656,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.711946052767104,
#        'lng': -79.53150957322656}],
#      'distance': 5419,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['2625 Weston (401)', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1561494509',
#     'hasPerk': False}]}}

# %%
#write the results into the data frame
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 1  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 2  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 3  [{'id': '4bf58dd8d48988d130941735', 'name': 'B...    False
# 4  [{'id': '4bf58dd8d48988d1c9941735', 'name': 'I...    False
#
#                          id  location.address location.cc location.city  \
# 0  566344c9498eedf4e11af0fa  3401 Dufferin St          CA       Toronto
# 1  4aedafd1f964a52025ce21e3  8 Kincort Street          CA       Toronto
# 2  51830da6498eafb14b40f22c  3500 Dufferin St          CA       Toronto
# 3  52430d7611d2b3a076a88132          Dufferin          CA       Toronto
# 4  4fca400ae4b0ba2d58c1a97f               NaN          CA           NaN
#
#   location.country     location.crossStreet  location.distance  \
# 0           Canada       Allen Road and 401               1304
# 1           Canada  Castlefield and Kincort               2346
# 2           Canada                      NaN                746
# 3           Canada                      NaN               1430
# 4           Canada                      NaN               1314
#
#                            location.formattedAddress  \
# 0  [3401 Dufferin St (Allen Road and 401), Toront...
# 1  [8 Kincort Street (Castlefield and Kincort), T...
# 2             [3500 Dufferin St, Toronto ON, Canada]
# 3                     [Dufferin, Toronto ON, Canada]
# 4                                           [Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.72668644119483...     43.726686
# 1  [{'label': 'display', 'lat': 43.69762110821487...     43.697621
# 2  [{'label': 'display', 'lat': 43.72034199204557...     43.720342
# 3  [{'label': 'display', 'lat': 43.70835683159475...     43.708357
# 4  [{'label': 'display', 'lat': 43.72617409960949...     43.726174
#
#    location.lng location.postalCode location.state  \
# 0    -79.453133             M6A 2T9             ON
# 1    -79.468550                 NaN             ON
# 2    -79.455828                 NaN             ON
# 3    -79.453877                 NaN             ON
# 4    -79.452317                 NaN            NaN
#
#                                         name    referralId
# 0                            Jamie's Italian  v-1561494509
# 1      Commisso Bros. & Racco Italian Bakery  v-1561494509
# 2                  San Genaro Italian Eatery  v-1561494509
# 3  Italian canadian savings and credit union  v-1561494509
# 4         La Paloma Italian Gelateria & Cafe  v-1561494509

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                          name            categories  \
# 0                             Jamie's Italian    Italian Restaurant
# 1       Commisso Bros. & Racco Italian Bakery    Italian Restaurant
# 2                   San Genaro Italian Eatery    Italian Restaurant
# 3   Italian canadian savings and credit union              Building
# 4          La Paloma Italian Gelateria & Cafe        Ice Cream Shop
# 5                    Cumpari's Italian Eatery    Italian Restaurant
# 6                        The Italian Sandwich          Trailer Park
# 7                                Italian Cafe  Fast Food Restaurant
# 8        Saggio Italian Eatery & Espresdo Bar    Italian Restaurant
# 9                     Catania Italian Cuisine    Italian Restaurant
# 10                    Agio Italian Ristorante    Italian Restaurant
# 11                               Il vagabondo    Italian Restaurant
# 12                             Dora's Italian    Italian Restaurant
# 13                Jolly II Italian Restaurant    Italian Restaurant
#
#                  address  cc     city country              crossStreet  \
# 0       3401 Dufferin St  CA  Toronto  Canada       Allen Road and 401
# 1       8 Kincort Street  CA  Toronto  Canada  Castlefield and Kincort
# 2       3500 Dufferin St  CA  Toronto  Canada                      NaN
# 3               Dufferin  CA  Toronto  Canada                      NaN
# 4                    NaN  CA      NaN  Canada                      NaN
# 5   3610 dufferin street  CA  Toronto  Canada          Dufferin/Wilson
# 6       242 Rushton Road  CA  Toronto  Canada                      NaN
# 7          2200 Yonge St  CA  Toronto  Canada                      NaN
# 8                    NaN  CA  Toronto  Canada                      NaN
# 9                    NaN  CA  Toronto  Canada                      NaN
# 10    1351 St Clair West  CA  Toronto  Canada                Lansdowne
# 11  2700 Dufferin Street  CA  Toronto  Canada                      NaN
# 12                   NaN  CA  Toronto  Canada                      NaN
# 13           2625 Weston  CA  Toronto  Canada                      401
#
#     distance                                   formattedAddress  \
# 0       1304  [3401 Dufferin St (Allen Road and 401), Toront...
# 1       2346  [8 Kincort Street (Castlefield and Kincort), T...
# 2        746             [3500 Dufferin St, Toronto ON, Canada]
# 3       1430                     [Dufferin, Toronto ON, Canada]
# 4       1314                                           [Canada]
# 5       1563  [3610 dufferin street (Dufferin/Wilson), Toron...
# 6       5197             [242 Rushton Road, Toronto ON, Canada]
# 7       5437                [2200 Yonge St, Toronto ON, Canada]
# 8       4536                               [Toronto ON, Canada]
# 9       5020                               [Toronto ON, Canada]
# 10      4852  [1351 St Clair West (Lansdowne), Toronto ON, C...
# 11      2140  [2700 Dufferin Street, Toronto ON m6b 4j3, Can...
# 12      5584                               [Toronto ON, Canada]
# 13      5419            [2625 Weston (401), Toronto ON, Canada]
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'label': 'display', 'lat': 43.72668644119483...  43.726686 -79.453133
# 1   [{'label': 'display', 'lat': 43.69762110821487...  43.697621 -79.468550
# 2   [{'label': 'display', 'lat': 43.72034199204557...  43.720342 -79.455828
# 3   [{'label': 'display', 'lat': 43.70835683159475...  43.708357 -79.453877
# 4   [{'label': 'display', 'lat': 43.72617409960949...  43.726174 -79.452317
# 5   [{'label': 'display', 'lat': 43.73211827821453...  43.732118 -79.459921
# 6   [{'label': 'display', 'lat': 43.680377, 'lng':...  43.680377 -79.427523
# 7   [{'label': 'display', 'lat': 43.72377014903966...  43.723770 -79.397573
# 8   [{'label': 'display', 'lat': 43.75834033292955...  43.758340 -79.476741
# 9   [{'label': 'display', 'lat': 43.680797, 'lng':...  43.680797 -79.430570
# 10  [{'label': 'display', 'lat': 43.67615560949629...  43.676156 -79.450574
# 11  [{'label': 'display', 'lat': 43.70147993924583...  43.701480 -79.452443
# 12  [{'label': 'display', 'lat': 43.76812, 'lng': ...  43.768120 -79.475147
# 13  [{'label': 'display', 'lat': 43.71194605276710...  43.711946 -79.531510
#
#    postalCode state                        id
# 0     M6A 2T9    ON  566344c9498eedf4e11af0fa
# 1         NaN    ON  4aedafd1f964a52025ce21e3
# 2         NaN    ON  51830da6498eafb14b40f22c
# 3         NaN    ON  52430d7611d2b3a076a88132
# 4         NaN   NaN  4fca400ae4b0ba2d58c1a97f
# 5     M3K 1N7    ON  52b5da0e498e96708cf1c974
# 6         NaN    ON  546e313c498ea838219b4ce7
# 7         NaN    ON  4b9fbb53f964a5206a3937e3
# 8         NaN    ON  4de3e16efa7651589f21395e
# 9         NaN    ON  4cfc22012d80a14304854fd8
# 10        NaN    ON  4e8218e1775b313c2afa5d8d
# 11    m6b 4j3    ON  4c4f0fa6fb742d7fda08542f
# 12        NaN    ON  4cfe726a084f54811f969009
# 13        NaN    ON  4b199b46f964a5205be023e3

# %%
dataframe_filtered.name
# Out:
# 0                               Jamie's Italian
# 1         Commisso Bros. & Racco Italian Bakery
# 2                     San Genaro Italian Eatery
# 3     Italian canadian savings and credit union
# 4            La Paloma Italian Gelateria & Cafe
# 5                      Cumpari's Italian Eatery
# 6                          The Italian Sandwich
# 7                                  Italian Cafe
# 8          Saggio Italian Eatery & Espresdo Bar
# 9                       Catania Italian Cuisine
# 10                      Agio Italian Ristorante
# 11                                 Il vagabondo
# 12                               Dora's Italian
# 13                  Jolly II Italian Restaurant
# Name: name, dtype: object

# %%
# create map of the venues withn 5000 radius of chosen latitude and longitude
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Chosen neighbourhood',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)
# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
